# %% [markdown]
# # Skin Type Classification - High Accuracy Training
# This notebook contains the pipeline to train a state-of-the-art skin type classifier (Oily, Dry, Normal) with >80% accuracy เป้าหมาย.
#
# ### Steps:
# 1. Download Dataset from Kaggle
# 2. Preprocess Data (Face Cropping)
# 3. Build Model (EfficientNetB0 Transfer Learning)
# 4. Train & Fine-tune
# 5. Export for Backend

# %%
# 1. Setup Kaggle and Download Data
# !pip install -q kaggle
from google.colab import files
files.upload() # Upload your kaggle.json here

# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d shubhamgoel27/oily-dry-and-normal-skin-types-dataset
# !unzip -q oily-dry-and-normal-skin-types-dataset.zip -d data/raw

# %%
# 2. Preprocessing (Face Cropping)
# This step is crucial to remove background noise and help the model focus on skin texture.
import os
import cv2
from Path import Path

# Copy the logic from prepare_data.py here or import it
# !python prepare_data.py

# %%
# 3. Training logic
# !python train.py

# %% [markdown]
# ### Why this works better than 38% accuracy:
# 1. **Face Cropping**: 38% accuracy often happens when the model learns background colors (like a blue wall) instead of skin features. Cropping forces it to look at the face.
# 2. **EfficientNet**: EfficientNet is much more powerful than simple CNNs for texture recognition.
# 3. **Data Augmentation**: We simulate different lighting and angles.
# 4. **Fine-Tuning**: We adapt the deep features of a model trained on millions of images to your specific task.
